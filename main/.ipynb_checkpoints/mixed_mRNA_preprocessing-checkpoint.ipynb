# %%
import pandas as pd
from pathlib import Path

# %%
# from the file: analisi_20241217_miRNAs_OPCs_Bowtie1_v_0_m_1_mismatch_align
# and the part: DEGs_FDR_5pc_NO_FC

# %%
path1 = Path("/Users/zainabnazari/mfuzz/data")

# %%
data_mRNA2_6 = pd.read_excel(path1/"mRNA_2_6_all.xlsx")

# %%
data_mRNA2_6.columns
# Out:
# Index(['Gene_Symbol', 'Gene_name', 'gene_type', 'ID', 'baseMean',
#        'log2FoldChange', 'lfcSE', 'stat', 'pvalue', 'padj'],
#       dtype='object')

# %%
data_mRNA2_6
# Out:
#       Gene_Symbol                                          Gene_name  \
# 0            Ngfr  nerve growth factor receptor (TNFR superfamily...
# 1             Fer  fer (fms/fps related) protein kinase [Source:M...
# 2          Gpr107  G protein-coupled receptor 107 [Source:MGI Sym...
# 3            Ins2       insulin II [Source:MGI Symbol;Acc:MGI:96573]
# 4            Gmpr  guanosine monophosphate reductase [Source:MGI ...
# ...           ...                                                ...
# 20761     Gm55763  predicted gene, 55763 [Source:MGI Symbol;Acc:M...
# 20762     Gm54922  predicted gene, 54922 [Source:MGI Symbol;Acc:M...
# 20763     Gm55617  predicted gene, 55617 [Source:MGI Symbol;Acc:M...
# 20764     Gm56324  predicted gene, 56324 [Source:MGI Symbol;Acc:M...
# 20765     Gm55070  predicted gene, 55070 [Source:MGI Symbol;Acc:M...
#
#             gene_type                  ID     baseMean  log2FoldChange  \
# 0      protein_coding  ENSMUSG00000000120   116.392155       -0.182776
# 1      protein_coding  ENSMUSG00000000127  1153.740468       -0.077744
# 2      protein_coding  ENSMUSG00000000194  1437.365519        0.015781
# 3      protein_coding  ENSMUSG00000000215    22.585220       -0.817323
# 4      protein_coding  ENSMUSG00000000253   249.705093        0.052584
# ...               ...                 ...          ...             ...
# 20761        misc_RNA  ENSMUSG00002076174    10.282084       -0.025954
# 20762           miRNA  ENSMUSG00002076443    10.589976       -0.249056
# 20763           miRNA  ENSMUSG00002076530    10.467248       -0.509901
# 20764           miRNA  ENSMUSG00002076731    10.838561        0.011472
# 20765           snRNA  ENSMUSG00002076902    10.660499       -1.359550
#
#           lfcSE      stat    pvalue      padj
# 0      0.201357 -0.907721  0.364026  0.542240
# 1      0.057736 -1.346538  0.178129  0.338514
# 2      0.033619  0.469392  0.638790  0.769183
# 3      0.313554 -2.606640  0.009144  0.051189
# 4      0.083350  0.630887  0.528114  0.685196
# ...         ...       ...       ...       ...
# 20761  0.395339 -0.065650  0.947656       NaN
# 20762  0.358618 -0.694489  0.487375       NaN
# 20763  0.465911 -1.094418  0.273772       NaN
# 20764  0.391210  0.029325  0.976606       NaN
# 20765  0.338605 -4.015154  0.000059       NaN
#
# [20766 rows x 10 columns]

# %%
# Check for duplicates in the 'miRNA_ID' column
duplicates = data_mRNA2_6[data_mRNA2_6['ID'].duplicated(keep=(False))]

# Print the duplicates
duplicates
# Out:
# Empty DataFrame
# Columns: [Gene_Symbol, Gene_name, gene_type, ID, baseMean, log2FoldChange, lfcSE, stat, pvalue, padj]
# Index: []

# %% [markdown]
# # Second file 6-12 Months

# %%
data_mRNA6_12 = pd.read_excel(path1/"mRNA_6M_12M.xlsx")

# %%
data_mRNA6_12
# Out:
#        Gene_Symbol                                          Gene_name  \
# 0             Pomc  pro-opiomelanocortin-alpha [Source:MGI Symbol;...
# 1          Vpreb1a  V-set pre-B cell surrogate light chain 1A [Sou...
# 2            Epcam  epithelial cell adhesion molecule [Source:MGI ...
# 3    2900040C04Rik  RIKEN cDNA 2900040C04 gene [Source:MGI Symbol;...
# 4           Defb11  defensin beta 11 [Source:MGI Symbol;Acc:MGI:21...
# ..             ...                                                ...
# 732          Cd79a  CD79A antigen (immunoglobulin-associated alpha...
# 733          Cd79b    CD79B antigen [Source:MGI Symbol;Acc:MGI:96431]
# 734            0.0                                   novel transcript
# 735        Gm37846  predicted gene, 37846 [Source:MGI Symbol;Acc:M...
# 736            NaN                                                NaN
#
#      Unnamed: 2       gene_type                  ID    baseMean  \
# 0           NaN  protein_coding  ENSMUSG00000020660   81.873234
# 1           NaN  protein_coding  ENSMUSG00000059305   12.754709
# 2           NaN  protein_coding  ENSMUSG00000045394   29.573298
# 3           NaN          lncRNA  ENSMUSG00000115625  171.008156
# 4           NaN  protein_coding  ENSMUSG00000045337   48.971125
# ..          ...             ...                 ...         ...
# 732         NaN  protein_coding  ENSMUSG00000003379   12.379511
# 733         NaN  protein_coding  ENSMUSG00000040592   12.047040
# 734         NaN          lncRNA  ENSMUSG00000121471   18.787849
# 735         NaN             TEC  ENSMUSG00000102610   13.010392
# 736         NaN          lncRNA  ENSMUSG00000142531   13.369055
#
#      log2FoldChange     lfcSE      stat        pvalue          padj
# 0         -2.421605  0.728792 -3.322767  8.912933e-04  3.154399e-02
# 1         -2.351522  0.442800 -5.310579  1.092777e-07  2.557350e-05
# 2         -2.064508  0.504746 -4.090191  4.310177e-05  3.441380e-03
# 3         -1.955364  0.319442 -6.121191  9.287862e-10  6.522875e-07
# 4         -1.951127  0.316356 -6.167512  6.937294e-10  5.649733e-07
# ..              ...       ...       ...           ...           ...
# 732        1.440166  0.369829  3.894140  9.854759e-05  6.159237e-03
# 733        1.515070  0.359632  4.212837  2.521828e-05  2.227269e-03
# 734        1.622566  0.355151  4.568663  4.908462e-06  5.646118e-04
# 735        1.978299  0.464442  4.259517  2.048691e-05  1.895970e-03
# 736        2.342963  0.460802  5.084533  3.685322e-07  6.468376e-05
#
# [737 rows x 11 columns]

# %%
# Check for duplicates in the 'miRNA_ID' column
duplicates = data_mRNA6_12[data_mRNA6_12['ID'].duplicated(keep=(False))]

# Print the duplicates
duplicates
# Out:
# Empty DataFrame
# Columns: [Gene_Symbol, Gene_name, Unnamed: 2, gene_type, ID, baseMean, log2FoldChange, lfcSE, stat, pvalue, padj]
# Index: []

# %% [markdown]
# # Now we have two files ready
# data_miRNA6_12, data_miRNA2_6

# %%
# renaming the columns 
fileA = data_mRNA2_6.rename(columns={'log2FoldChange': 'FC_2_6'})
fileB = data_mRNA6_12.rename(columns={'log2FoldChange': 'FC_6_12'})

# %%
fileB
# Out:
#        Gene_Symbol                                          Gene_name  \
# 0             Pomc  pro-opiomelanocortin-alpha [Source:MGI Symbol;...
# 1          Vpreb1a  V-set pre-B cell surrogate light chain 1A [Sou...
# 2            Epcam  epithelial cell adhesion molecule [Source:MGI ...
# 3    2900040C04Rik  RIKEN cDNA 2900040C04 gene [Source:MGI Symbol;...
# 4           Defb11  defensin beta 11 [Source:MGI Symbol;Acc:MGI:21...
# ..             ...                                                ...
# 732          Cd79a  CD79A antigen (immunoglobulin-associated alpha...
# 733          Cd79b    CD79B antigen [Source:MGI Symbol;Acc:MGI:96431]
# 734            0.0                                   novel transcript
# 735        Gm37846  predicted gene, 37846 [Source:MGI Symbol;Acc:M...
# 736            NaN                                                NaN
#
#      Unnamed: 2       gene_type                  ID    baseMean   FC_6_12  \
# 0           NaN  protein_coding  ENSMUSG00000020660   81.873234 -2.421605
# 1           NaN  protein_coding  ENSMUSG00000059305   12.754709 -2.351522
# 2           NaN  protein_coding  ENSMUSG00000045394   29.573298 -2.064508
# 3           NaN          lncRNA  ENSMUSG00000115625  171.008156 -1.955364
# 4           NaN  protein_coding  ENSMUSG00000045337   48.971125 -1.951127
# ..          ...             ...                 ...         ...       ...
# 732         NaN  protein_coding  ENSMUSG00000003379   12.379511  1.440166
# 733         NaN  protein_coding  ENSMUSG00000040592   12.047040  1.515070
# 734         NaN          lncRNA  ENSMUSG00000121471   18.787849  1.622566
# 735         NaN             TEC  ENSMUSG00000102610   13.010392  1.978299
# 736         NaN          lncRNA  ENSMUSG00000142531   13.369055  2.342963
#
#         lfcSE      stat        pvalue          padj
# 0    0.728792 -3.322767  8.912933e-04  3.154399e-02
# 1    0.442800 -5.310579  1.092777e-07  2.557350e-05
# 2    0.504746 -4.090191  4.310177e-05  3.441380e-03
# 3    0.319442 -6.121191  9.287862e-10  6.522875e-07
# 4    0.316356 -6.167512  6.937294e-10  5.649733e-07
# ..        ...       ...           ...           ...
# 732  0.369829  3.894140  9.854759e-05  6.159237e-03
# 733  0.359632  4.212837  2.521828e-05  2.227269e-03
# 734  0.355151  4.568663  4.908462e-06  5.646118e-04
# 735  0.464442  4.259517  2.048691e-05  1.895970e-03
# 736  0.460802  5.084533  3.685322e-07  6.468376e-05
#
# [737 rows x 11 columns]

# %%
merged_df = pd.merge(fileA[['ID','baseMean', 'FC_2_6']], fileB[['ID', 'FC_6_12']], on='ID')

# %%
merged_df
# Out:
#                      ID     baseMean    FC_2_6   FC_6_12
# 0    ENSMUSG00000000120   116.392155 -0.182776 -1.046293
# 1    ENSMUSG00000000127  1153.740468 -0.077744  0.182205
# 2    ENSMUSG00000000194  1437.365519  0.015781 -0.123912
# 3    ENSMUSG00000000215    22.585220 -0.817323 -1.267013
# 4    ENSMUSG00000000253   249.705093  0.052584 -0.283247
# ..                  ...          ...       ...       ...
# 732  ENSMUSG00000136702   121.044694  0.337610  0.542064
# 733  ENSMUSG00000139001    43.133424 -1.233945 -1.562018
# 734  ENSMUSG00000141743    13.929759  0.204093  1.385601
# 735  ENSMUSG00000141955   185.595693 -1.174173 -1.153382
# 736  ENSMUSG00000142531    13.369055 -0.330767  2.342963
#
# [737 rows x 4 columns]

# %%
merged_df.to_excel(path1/"merged_mixed_mRNA.xlsx", index=False)
