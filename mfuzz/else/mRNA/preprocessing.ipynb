# %%
import pandas as pd
from pathlib import Path

# %%
path1 = Path("/Users/zainabnazari/mfuzz/data")

# %%
data_mRNA2_6 = pd.read_excel(path1/"mRNA_2M_6M.xlsx")

# %%
data_mRNA2_6.columns
# Out:
# Index(['Gene_Symbol', 'Gene_name', 'gene_type', 'ID', 'baseMean',
#        'log2FoldChange', 'lfcSE', 'stat', 'pvalue', 'padj'],
#       dtype='object')

# %%
data_mRNA2_6
# Out:
#         Gene_Symbol                                          Gene_name  \
# 0     4930402D18Rik  RIKEN cDNA 4930402D18 gene [Source:MGI Symbol;...
# 1             Ckap2  cytoskeleton associated protein 2 [Source:MGI ...
# 2            Kif20a  kinesin family member 20A [Source:MGI Symbol;A...
# 3             Cdcp3  CUB domain containing protein 3 [Source:MGI Sy...
# 4           Gm42697  predicted gene 42697 [Source:MGI Symbol;Acc:MG...
# ...             ...                                                ...
# 3421            0.0                                   novel transcript
# 3422          Hnf1b  HNF1 homeobox B [Source:MGI Symbol;Acc:MGI:98505]
# 3423           Scg2  secretogranin II [Source:MGI Symbol;Acc:MGI:10...
# 3424        Gm48530  predicted gene, 48530 [Source:MGI Symbol;Acc:M...
# 3425           Pomc  pro-opiomelanocortin-alpha [Source:MGI Symbol;...
#
#            gene_type                  ID    baseMean  log2FoldChange  \
# ...

# %%
# Check for duplicates in the 'miRNA_ID' column
duplicates = data_mRNA2_6[data_mRNA2_6['ID'].duplicated(keep=(False))]

# Print the duplicates
duplicates
# Out:
# Empty DataFrame
# Columns: [Gene_Symbol, Gene_name, gene_type, ID, baseMean, log2FoldChange, lfcSE, stat, pvalue, padj]
# Index: []

# %% [markdown]
# # Second file 6-16 Months

# %%
data_mRNA6_12 = pd.read_excel(path1/"mRNA_6M_12M.xlsx")

# %%
data_mRNA6_12
# Out:
#        Gene_Symbol                                          Gene_name  \
# 0             Pomc  pro-opiomelanocortin-alpha [Source:MGI Symbol;...
# 1          Vpreb1a  V-set pre-B cell surrogate light chain 1A [Sou...
# 2            Epcam  epithelial cell adhesion molecule [Source:MGI ...
# 3    2900040C04Rik  RIKEN cDNA 2900040C04 gene [Source:MGI Symbol;...
# 4           Defb11  defensin beta 11 [Source:MGI Symbol;Acc:MGI:21...
# ..             ...                                                ...
# 732          Cd79a  CD79A antigen (immunoglobulin-associated alpha...
# 733          Cd79b    CD79B antigen [Source:MGI Symbol;Acc:MGI:96431]
# 734            0.0                                   novel transcript
# 735        Gm37846  predicted gene, 37846 [Source:MGI Symbol;Acc:M...
# 736            NaN                                                NaN
#
#      Unnamed: 2       gene_type                  ID    baseMean  \
# ...

# %%
# Check for duplicates in the 'miRNA_ID' column
duplicates = data_mRNA6_12[data_mRNA6_12['ID'].duplicated(keep=(False))]

# Print the duplicates
duplicates
# Out:
# Empty DataFrame
# Columns: [Gene_Symbol, Gene_name, Unnamed: 2, gene_type, ID, baseMean, log2FoldChange, lfcSE, stat, pvalue, padj]
# Index: []

# %% [markdown]
# # Now we have two files ready
# data_mRNA6_12, data_mRNA2_6

# %%
# renaming the columns 
fileA = data_mRNA2_6.rename(columns={'log2FoldChange': 'FC_2_6'})
fileB = data_mRNA6_12.rename(columns={'log2FoldChange': 'FC_6_12'})

# %%
fileA
# Out:
#         Gene_Symbol                                          Gene_name  \
# 0     4930402D18Rik  RIKEN cDNA 4930402D18 gene [Source:MGI Symbol;...
# 1             Ckap2  cytoskeleton associated protein 2 [Source:MGI ...
# 2            Kif20a  kinesin family member 20A [Source:MGI Symbol;A...
# 3             Cdcp3  CUB domain containing protein 3 [Source:MGI Sy...
# 4           Gm42697  predicted gene 42697 [Source:MGI Symbol;Acc:MG...
# ...             ...                                                ...
# 3421            0.0                                   novel transcript
# 3422          Hnf1b  HNF1 homeobox B [Source:MGI Symbol;Acc:MGI:98505]
# 3423           Scg2  secretogranin II [Source:MGI Symbol;Acc:MGI:10...
# 3424        Gm48530  predicted gene, 48530 [Source:MGI Symbol;Acc:M...
# 3425           Pomc  pro-opiomelanocortin-alpha [Source:MGI Symbol;...
#
#            gene_type                  ID    baseMean    FC_2_6     lfcSE  \
# ...

# %%
merged_df_mRNA = pd.merge(fileA[['ID', 'FC_2_6']], fileB[['ID', 'FC_6_12']], on='ID')

# %%
merged_df_mRNA
# Out:
#                      ID    FC_2_6   FC_6_12
# 0    ENSMUSG00000092879 -1.653149 -1.187133
# 1    ENSMUSG00000077767 -1.529833 -1.144063
# 2    ENSMUSG00000127502 -1.515497 -1.492482
# 3    ENSMUSG00000068428 -1.372453 -1.055680
# 4    ENSMUSG00000026581 -1.354312  1.387679
# ..                  ...       ...       ...
# 352  ENSMUSG00000105594  0.721754  0.697024
# 353  ENSMUSG00000064369  0.753155 -0.877004
# 354  ENSMUSG00000110924  0.832370  0.896269
# 355  ENSMUSG00000004707  1.086365  0.940595
# 356  ENSMUSG00000020660  2.371552 -2.421605
#
# [357 rows x 3 columns]

# %%
merged_df_mRNA.to_excel(path1/"merged_df_mRNA.xlsx")
