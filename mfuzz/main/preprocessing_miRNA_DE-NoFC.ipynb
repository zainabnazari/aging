# %%
import pandas as pd
from pathlib import Path

# %%
# from the file: analisi_20241217_miRNAs_OPCs_Bowtie1_v_0_m_1_mismatch_align
# and the part: DEGs_FDR_5pc_NO_FC

# %%
path1 = Path("/Users/zainabnazari/mfuzz/data")

# %%
data_miRNA2_6 = pd.read_excel(path1/"miRNA-2M_6M.xlsx")

# %%
data_miRNA2_6.columns
# Out:
# Index(['Unnamed: 0', 'sequence', 'baseMean', 'log2FoldChange', 'lfcSE', 'stat',
#        'pvalue', 'padj'],
#       dtype='object')

# %%
data_miRNA2_6.rename(columns={'Unnamed: 0': 'miRNA_ID'}, inplace=True)

# %%
data_miRNA2_6
# Out:
#            miRNA_ID                    sequence    baseMean  log2FoldChange  \
# 0   mmu-miR-6974-3p      TCTCCACTCTCTTCTGTCCCAG   10.784080       -6.550344
# 1    mmu-miR-675-5p      TGGTGCGGAAAGGGCCCACAGT    7.144822       -5.580442
# 2   mmu-miR-129b-3p     CAAGCCCAGACCGCAAAAAGATT    5.694855       -5.572762
# 3   mmu-miR-181d-3p       CCCACCGGGGGATGAATGTCA   16.572296       -4.070777
# 4    mmu-miR-10b-5p     TACCCTGTAGAACCGAATTTGTG  344.224610       -1.954425
# ..              ...                         ...         ...             ...
# 72   mmu-miR-344-5p  AGTCAGGCTCCTGGCTAGATTCCAGG   12.060903        4.307251
# 73     mmu-miR-8117       GCTCGTGTGGAACAGAAGGGG    9.706193        4.813948
# 74     mmu-miR-6353     TAGCAGCACGTATTTATCCTATT    4.758087        4.902113
# 75   mmu-miR-668-5p    GTAAGTGTGCCTCGGGTGAGCATG    5.999869        6.069480
# 76   mmu-miR-185-3p       AGGGGCTGGCTTTCCTCTGGT    6.809896        6.356488
#
#        lfcSE      stat        pvalue      padj
# 0   1.827439 -3.584438  3.378043e-04  0.007408
# 1   1.355377 -4.117262  3.834001e-05  0.001756
# 2   1.813532 -3.072878  2.120049e-03  0.030039
# 3   0.873359 -4.661058  3.145883e-06  0.000207
# 4   0.387569 -5.042775  4.588297e-07  0.000060
# ..       ...       ...           ...       ...
# 72  1.285660  3.350226  8.074556e-04  0.014582
# 73  1.419671  3.390889  6.966635e-04  0.012833
# 74  1.615852  3.033764  2.415230e-03  0.033703
# 75  1.631256  3.720741  1.986390e-04  0.004961
# 76  1.612698  3.941523  8.096577e-05  0.002785
#
# [77 rows x 8 columns]

# %%
# Check for duplicates in the 'miRNA_ID' column
duplicates = data_miRNA2_6[data_miRNA2_6['miRNA_ID'].duplicated(keep=(False))]

# Print the duplicates
duplicates
# Out:
# Empty DataFrame
# Columns: [miRNA_ID, sequence, baseMean, log2FoldChange, lfcSE, stat, pvalue, padj]
# Index: []

# %% [markdown]
# # Second file 6-12 Months

# %%
data_miRNA6_12 = pd.read_excel(path1/"miRNA-6M_12M.xlsx")

# %%
data_miRNA6_12
# Out:
#          Unnamed: 0                  sequence      baseMean  log2FoldChange  \
# 0   mmu-miR-1264-3p    CAAATCTTATTTGAGCACCTGT  14997.868751       -2.553652
# 1   mmu-miR-1298-5p    TTCATTCGGCTGTCCAGATGTA  16975.985098       -2.108564
# 2      mmu-miR-5099      TTAGATCGATGTGGTGCTCC     71.879288       -2.086749
# 3    mmu-miR-448-3p    TTGCATATGTAGGATGTCCCAT   2293.849997       -1.881322
# 4    mmu-miR-20a-3p    ACTGCATTACGAGCACTTAAAG    116.166191       -1.780963
# ..              ...                       ...           ...             ...
# 79   mmu-miR-874-3p    CTGCCCTGGCCCGAGGGACCGA    754.812407        0.902743
# 80   mmu-miR-491-5p    AGTGGGGAACCCTTCCATGAGG    108.902138        0.972796
# 81   mmu-miR-92b-5p  AGGGACGGGACGTGGTGCAGTGTT    165.425855        1.032048
# 82   mmu-miR-770-5p    AGCACCACGTGTCTGGGCCACG    445.481180        1.138875
# 83   mmu-miR-323-5p    AGGTGGTCCGTGGCGCGTTCGC    160.345824        1.532001
#
#        lfcSE      stat        pvalue          padj
# 0   0.367496 -6.948786  3.684442e-12  1.484830e-09
# 1   0.344318 -6.123887  9.131943e-10  1.226724e-07
# 2   0.500870 -4.166246  3.096571e-05  6.623148e-04
# 3   0.290709 -6.471497  9.703652e-11  1.955286e-08
# 4   0.584516 -3.046901  2.312136e-03  1.901614e-02
# ..       ...       ...           ...           ...
# 79  0.252306  3.577972  3.462701e-04  4.983816e-03
# 80  0.365200  2.663737  7.727802e-03  4.208519e-02
# 81  0.361379  2.855861  4.292034e-03  2.745539e-02
# 82  0.398091  2.860843  4.225164e-03  2.745539e-02
# 83  0.526154  2.911700  3.594680e-03  2.534370e-02
#
# [84 rows x 8 columns]

# %%
data_miRNA6_12.rename(columns={'Unnamed: 0': 'miRNA_ID'}, inplace=True)

# %%
data_miRNA6_12
# Out:
#            miRNA_ID                  sequence      baseMean  log2FoldChange  \
# 0   mmu-miR-1264-3p    CAAATCTTATTTGAGCACCTGT  14997.868751       -2.553652
# 1   mmu-miR-1298-5p    TTCATTCGGCTGTCCAGATGTA  16975.985098       -2.108564
# 2      mmu-miR-5099      TTAGATCGATGTGGTGCTCC     71.879288       -2.086749
# 3    mmu-miR-448-3p    TTGCATATGTAGGATGTCCCAT   2293.849997       -1.881322
# 4    mmu-miR-20a-3p    ACTGCATTACGAGCACTTAAAG    116.166191       -1.780963
# ..              ...                       ...           ...             ...
# 79   mmu-miR-874-3p    CTGCCCTGGCCCGAGGGACCGA    754.812407        0.902743
# 80   mmu-miR-491-5p    AGTGGGGAACCCTTCCATGAGG    108.902138        0.972796
# 81   mmu-miR-92b-5p  AGGGACGGGACGTGGTGCAGTGTT    165.425855        1.032048
# 82   mmu-miR-770-5p    AGCACCACGTGTCTGGGCCACG    445.481180        1.138875
# 83   mmu-miR-323-5p    AGGTGGTCCGTGGCGCGTTCGC    160.345824        1.532001
#
#        lfcSE      stat        pvalue          padj
# 0   0.367496 -6.948786  3.684442e-12  1.484830e-09
# 1   0.344318 -6.123887  9.131943e-10  1.226724e-07
# 2   0.500870 -4.166246  3.096571e-05  6.623148e-04
# 3   0.290709 -6.471497  9.703652e-11  1.955286e-08
# 4   0.584516 -3.046901  2.312136e-03  1.901614e-02
# ..       ...       ...           ...           ...
# 79  0.252306  3.577972  3.462701e-04  4.983816e-03
# 80  0.365200  2.663737  7.727802e-03  4.208519e-02
# 81  0.361379  2.855861  4.292034e-03  2.745539e-02
# 82  0.398091  2.860843  4.225164e-03  2.745539e-02
# 83  0.526154  2.911700  3.594680e-03  2.534370e-02
#
# [84 rows x 8 columns]

# %%
# Check for duplicates in the 'miRNA_ID' column
duplicates = data_miRNA6_12[data_miRNA6_12['miRNA_ID'].duplicated(keep=(False))]

# Print the duplicates
duplicates
# Out:
# Empty DataFrame
# Columns: [miRNA_ID, sequence, baseMean, log2FoldChange, lfcSE, stat, pvalue, padj]
# Index: []

# %% [markdown]
# # Now we have two files ready
# data_miRNA6_12, data_miRNA2_6

# %%
# renaming the columns 
fileA = data_miRNA2_6.rename(columns={'log2FoldChange': 'FC_2_6'})
fileB = data_miRNA6_12.rename(columns={'log2FoldChange': 'FC_6_12'})

# %%
fileB
# Out:
#            miRNA_ID                  sequence      baseMean   FC_6_12  \
# 0   mmu-miR-1264-3p    CAAATCTTATTTGAGCACCTGT  14997.868751 -2.553652
# 1   mmu-miR-1298-5p    TTCATTCGGCTGTCCAGATGTA  16975.985098 -2.108564
# 2      mmu-miR-5099      TTAGATCGATGTGGTGCTCC     71.879288 -2.086749
# 3    mmu-miR-448-3p    TTGCATATGTAGGATGTCCCAT   2293.849997 -1.881322
# 4    mmu-miR-20a-3p    ACTGCATTACGAGCACTTAAAG    116.166191 -1.780963
# ..              ...                       ...           ...       ...
# 79   mmu-miR-874-3p    CTGCCCTGGCCCGAGGGACCGA    754.812407  0.902743
# 80   mmu-miR-491-5p    AGTGGGGAACCCTTCCATGAGG    108.902138  0.972796
# 81   mmu-miR-92b-5p  AGGGACGGGACGTGGTGCAGTGTT    165.425855  1.032048
# 82   mmu-miR-770-5p    AGCACCACGTGTCTGGGCCACG    445.481180  1.138875
# 83   mmu-miR-323-5p    AGGTGGTCCGTGGCGCGTTCGC    160.345824  1.532001
#
#        lfcSE      stat        pvalue          padj
# 0   0.367496 -6.948786  3.684442e-12  1.484830e-09
# 1   0.344318 -6.123887  9.131943e-10  1.226724e-07
# 2   0.500870 -4.166246  3.096571e-05  6.623148e-04
# 3   0.290709 -6.471497  9.703652e-11  1.955286e-08
# 4   0.584516 -3.046901  2.312136e-03  1.901614e-02
# ..       ...       ...           ...           ...
# 79  0.252306  3.577972  3.462701e-04  4.983816e-03
# 80  0.365200  2.663737  7.727802e-03  4.208519e-02
# 81  0.361379  2.855861  4.292034e-03  2.745539e-02
# 82  0.398091  2.860843  4.225164e-03  2.745539e-02
# 83  0.526154  2.911700  3.594680e-03  2.534370e-02
#
# [84 rows x 8 columns]

# %%
merged_df = pd.merge(fileA[['miRNA_ID', 'FC_2_6']], fileB[['miRNA_ID', 'FC_6_12']], on='miRNA_ID')

# %%
merged_df
# Out:
#            miRNA_ID    FC_2_6   FC_6_12
# 0    mmu-miR-10b-5p -1.954425 -1.078278
# 1   mmu-miR-1264-3p -1.435970 -2.553652
# 2    mmu-miR-448-3p -1.389448 -1.881322
# 3   mmu-miR-1298-3p -1.344444 -1.186487
# 4   mmu-miR-1298-5p -1.332344 -2.108564
# 5   mmu-miR-1264-5p -1.331243 -1.037213
# 6    mmu-miR-666-5p -1.119025  0.845991
# 7   mmu-miR-467a-5p -0.964038 -0.907717
# 8    mmu-miR-34c-5p -0.950259 -0.683349
# 9    mmu-miR-100-5p -0.825334 -0.897539
# 10   mmu-miR-204-5p -0.724089 -0.647708
# 11   mmu-miR-409-5p -0.722926 -0.987302
# 12   mmu-miR-204-3p -0.617762 -0.683519
# 13      mmu-miR-484 -0.509422 -0.406089
# 14   mmu-miR-151-5p -0.501917  0.550314
# 15   mmu-miR-434-3p  0.645608  0.444244
# 16    mmu-miR-33-5p  1.003831 -1.020228

# %%
merged_df.to_excel(path1/"merged_noFC_miRNA.xlsx", index=False)
